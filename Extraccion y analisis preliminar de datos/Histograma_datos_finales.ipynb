# %% [markdown]
# ### Importacion de librerias necesarias

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import argparse
import pandas as pd

# %% [markdown]
# ### Cargar los datos recopilados

# %%
datos=pd.read_csv("Data_clean_Completo4.csv")
variables =["Solute_Mol_Mass", "Num_Cations", "Num_Anions", "Temperature_C", "Solvent_Mol_Mass", "Molal","Molal_Activity_Coefficient", "Osmotic_Coefficient"]

# %% [markdown]
# ### Visualizacion histograma de todas las variables.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


X_y = datos.iloc[:, [1, 2, 3, 6,7, 8, 9, 10]]

    
X_y.hist(bins=10, figsize=(20,15))
plt.savefig("histograma.png") 
plt.show()

plt.close()
